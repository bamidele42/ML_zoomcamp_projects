# %%
import tensorflow as tf

from tensorflow import keras

# %%
# Loading the model
model = keras.models.load_model("/kaggle/input/dog_cat_model/keras/classification-model/1/xception_v4_03_0.986.keras")

# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.xception import preprocess_input
import numpy as np
img_path = "/kaggle/input/one-instance/dog_461.jpg"

# %%
img = load_img(img_path, target_size=(299, 299))

# Turning the image into numpy array
x = np.array(img)
X = np.array([x])

X = preprocess_input(X)

preds = model.predict(X)

# %%
# getting the classes in a list
classes = ['cats','dogs']

# %%
# join the classes to the prediction
dict(zip(classes, preds[0]))
# Out:
# {'cats': -7.0652943, 'dogs': 2.8839655}

# %% [markdown]
# ### Using Tensorflow lite
# i will convert the model to tensorflow lite format

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()

with open("dog_cat_model.tflite", "wb") as f_out:
    f_out.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpdfhxzz0n'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name='input_layer_50')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   136087348250576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348260960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348263072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348256384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348258672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348262368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348431328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348435728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348432384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348435024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348438544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348439072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348439248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348442944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348440304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348439600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348529280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348528752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348532800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348528576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348530160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348534208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348539664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348537904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348538432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348537552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348541952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348577552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348581600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348577376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348578960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348585824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348585296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348591456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348585472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348589344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348585120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348586704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348658768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348658944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348667744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348667216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348667392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348671264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348667040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348668624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348666336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348672320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348745968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348741216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348744736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348742624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348743504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348748080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348751776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348749840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348750544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348748608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348754240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348839520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348843040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348840928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348841808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348847264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348846736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348846912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348850784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348846560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348848144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348854480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348851840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348905056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348907872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348904352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348906640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348913504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348912976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348913152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348917024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348912800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348914384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348912096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348918080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069508704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069512224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069510112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069510992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069516448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069515920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069516096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069519968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069515744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069517328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069515040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069522432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069574416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069578464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069574240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069575824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069582688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069582160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069582336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069586208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069581984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069583568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348254448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087348263600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069657392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069658096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069587968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069655984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069663728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069663200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069663376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069667248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069663024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069664608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069670944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069705136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069707952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069707072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069706720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069712176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069711648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069711824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069715696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069711472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069713056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069710768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069718160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069806080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069806960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069803088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069805728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069811184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069810656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069810832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069814704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069810480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069812064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069818400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069815760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069852592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069855408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069854528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069854176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069861040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069860512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069860688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069864560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069860336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069861920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069859632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069865616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069953536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069954416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069950544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069953184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069958640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069958112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069958288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069962160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069957936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069959520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069957232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087069964624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070016608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070020656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070016432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070018016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070024880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070024352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070024528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070028400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070024176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070025760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070023472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070029456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070100992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070101872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070098000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070100640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070107504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070106976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070107152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070111024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070106800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070108384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070106096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070112080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070180448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070184496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070180272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070181856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070188720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070188192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070188368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070192240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070188016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070189600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070187312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070296368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070295840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070299888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070295664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070297248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070304112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070303584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070309744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070303760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070307632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070303408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070304992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070363488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070364016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070360672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070362784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070368240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070367712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070367888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070371760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070367536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070369120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070375456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070372816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070426032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070428848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070427968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070427616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087070429376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087068672944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087068675936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136087068673472: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# #### Loading the model with TFlite

# %%
import tensorflow.lite as tflite

# %%
interpreter = tflite.Interpreter(model_path= "/kaggle/working/dog_cat_model.tflite")
interpreter.allocate_tensors()

# Getting the index of the input
input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]

# %%
# Setting the tensors with the input data
interpreter.set_tensor(input_index, X)
interpreter.invoke()
preds = interpreter.get_tensor(output_index)

# %%
classes = ['cats','dogs']
dict(zip(classes, pred[0]))
# Out:
# {'cats': -7.0652943, 'dogs': 2.8839655}

# %% [markdown]
# ### Removing Tensorflow Dependencies

# %%
from PIL import Image

# %%
with Image.open(img_path) as img:
    img = img.resize((299, 299), Image.NEAREST)

# %%
def preprocess_input(x):
    x /= 127.5
    x -= 1.
    return x

# %%
# Turning the image into numpy array
x = np.array(img, dtype="float32")
X = np.array([x])

X = preprocess_input(X)

# %%
interpreter.set_tensor(input_index, X)
interpreter.invoke()
preds = interpreter.get_tensor(output_index)

# %%
classes = ['cats','dogs']
dict(zip(classes, pred[0]))
# Out:
# {'cats': -7.0652943, 'dogs': 2.8839655}

# %% [markdown]
# #### A simpler way of doing this

# %%
# !pip install keras_image_helper
# Out:
# Collecting keras_image_helper
#   Downloading keras_image_helper-0.0.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras_image_helper) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from keras_image_helper) (11.0.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->keras_image_helper) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->keras_image_helper) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->keras_image_helper) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->keras_image_helper) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->keras_image_helper) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->keras_image_helper) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->keras_image_helper) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->keras_image_helper) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->keras_image_helper) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->keras_image_helper) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->keras_image_helper) (2024.2.0)
# Downloading keras_image_helper-0.0.1-py3-none-any.whl (4.6 kB)
# Installing collected packages: keras_image_helper
# Successfully installed keras_image_helper-0.0.1

# %%
# Installing tensorflow lite
# !pip install --extra-index-url https://google-coral.github.io/py-repo/ tflite_runtime

# %%
import tflite_runtime.interpreter as tflite
from keras_image_helper import create_preprocessor

# %%
interpreter.get_output_details()[0]["index"]
# Out:
# 229

# %%
interpreter = tflite.Interpreter(model_path = "dog_cat_model.tflite")
interpreter.allocate_tensors()
input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]

# %%
preprocessor = create_preprocessor("xception", target_size=(299, 299))

# %%
X= preprocessor.from_path(img_path)

# %%
interpreter.set_tensor(input_index, X)
interpreter.invoke()
preds = interpreter.get_tensor(output_index)

# %%
classes = ['cats','dogs']
dict(zip(classes, pred[0]))
# Out:
# {'cats': -7.0652943, 'dogs': 2.8839655}

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://google-coral.github.io/py-repo/
# Collecting tflite_runtime
#   Downloading tflite_runtime-2.14.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.10/dist-packages (from tflite_runtime) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.2->tflite_runtime) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.2->tflite_runtime) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.2->tflite_runtime) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.2->tflite_runtime) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.2->tflite_runtime) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.2->tflite_runtime) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.23.2->tflite_runtime) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.23.2->tflite_runtime) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->tflite_runtime) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.23.2->tflite_runtime) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.23.2->tflite_runtime) (2024.2.0)
# Downloading tflite_runtime-2.14.0-cp310-cp310-manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 31.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: tflite_runtime
# Successfully installed tflite_runtime-2.14.0
